# %% [markdown]
# # Plotly Tutorial
# <i> https://www.youtube.com/watch?v=GGL6U0k8WYA

# %% [markdown]
# pip install plotly, chart_studio, pandas, matplotlib, cufflinks, seaborn, jupyter

# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <function cufflinks.offline.go_offline(connected=None)>

# %% [markdown]
# ## Basics

# %%
arr_1 = np.random.randn(50,4)
df_1 = pd.DataFrame(arr_1, columns=['A', 'B','C','D'])
df_1.head()
df_1.plot()
# Out:
# <AxesSubplot:>

# %%
df_stocks = px.data.stocks() 
px.line(df_stocks, x='date', y='GOOG', labels={'x': 'Date', 'y':'Price'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
px.line(df_stock, x='date', y=['GOOG', 'AAPL'], labels={'x':'date', 'y':'price'}, title='Apple vs Google')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.AAPL,
                         mode='lines+markers', name='Apple',
                         line=dict(color='firebrick', width=2, 
                                   dash='dash')))
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.AMZN,
                         mode='lines+markers', name='Amazon',
                         line=dict(color='black', width=2, 
                                   dash='dashdot')))
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.GOOG,
                         mode='lines+markers', name='Google',
                         line=dict(color='green', width=2, 
                                   dash='dot')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
fig.update_layout(title='Stock Price Data 2018 – 2020', xaxis_title='Price', yaxis_title='Date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
fig.update_layout(
    xaxis=dict(
        showline=True
        ,showgrid=True
        ,showticklabels=True
        ,linecolor='rgb(204,204,204)'
        ,linewidth=2
        ,ticks='outside'
        ,tickfont=dict(
            family='Arial'
            ,size=12
            ,color='rgb(82,82,82)'
        ),
    ),
    yaxis=dict(showgrid=False,
               zeroline=False
               ,showline=False
               ,showticklabels=False),
    autosize=False,
    margin=dict(
        autoexpand=False, l=100, r=20, t=110, ),
    showlegend=False,
    plot_bgcolor='white'
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\lsedm\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...
